# %% [markdown]
# Estudo Dados Airbnb Rotterdam

# %%
#Import das bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

#carregamento do Data_frame para o programa
listings_df=pd.read_csv('listings.csv')
#listings_df=pd.read_csv('listings1.csv')
#listings_df=pd.read_csv('neighbourhoods.csv')
#listings_df=pd.read_csv('reviews - comentarios.csv')
#listings_df=pd.read_csv('reviews.csv')

# %%
listings_df
# Out:
#                       id                                               name  \
# 0                  73155  Rental unit in Rotterdam · ★4.95 · 1 bedroom ·...
# 1                  77592  Rental unit in Rotterdam · ★4.78 · 1 bedroom ·...
# 2                 101526  Condo in Rotterdam · ★4.83 · 1 bedroom · 1 bed...
# 3                 283124  Rental unit in Rotterdam · ★4.72 · 2 bedrooms ...
# 4                 539905  Condo in Rotterdam · ★4.92 · 1 bedroom · 1 bed...
# ...                  ...                                                ...
# 1035  978152696454987784  Rental unit in Rotterdam · ★New · 1 bedroom · ...
# 1036  978275266721990389  Rental unit in Rotterdam · ★New · 1 bedroom · ...
# 1037  980130608467858999  Rental unit in Rotterdam · ★New · 1 bedroom · ...
# 1038  981654772511634105  Cabin in Hoek van Holland · ★New · 3 bedrooms ...
# 1039  981709353935149597  Rental unit in Rotterdam · ★New · 1 bedroom · ...
#
# ...

# %%
row = listings_df['name']

for index, palavra in enumerate(row):
    for indice, letra in enumerate(palavra):
        if letra =='★':
                if palavra[indice+1] != 'N' :
                    avaliacao = palavra[indice + 1: indice + 5]
                    listings_df.loc[index, 'avaliacao'] = float(avaliacao)
                    break;
                else:
                    #avaliacao = palavra[indice + 1: indice + 4]
                    listings_df.loc[index, 'avaliacao'] = 0
                    break;
        
#listings_df['avaliacao']


bairro = pd.DataFrame(listings_df.groupby('neighbourhood_group')['avaliacao'].mean())
bairro['preco_medio'] = listings_df.groupby('neighbourhood_group')['price'].mean()

print(bairro)
# Out:
#                              avaliacao  preco_medio
# neighbourhood_group
# Botlek-Europoort-Maasvlakte   4.410000    80.000000
# Charlois                      4.093111   106.647059
# Delfshaven                    4.407500   149.687179
# Feijenoord                    4.524684   176.010638
# Hillegersberg-Schiebroek      4.379130   162.132075
# Hoek van Holland              3.846471   119.823529
# Hoogvliet                     5.000000   816.666667
# IJsselmonde                   4.856250   144.555556
# Kralingen-Crooswijk           4.477215   149.463918
# Noord                         4.500686   132.520737
# Overschie                     4.800000   132.650000
# Pernis                        4.800000    90.000000
# Prins Alexander               3.929286   123.777778
# Rotterdam Centrum             4.501244   174.795082
# Rozenburg                     4.880000   199.000000
# Waalhaven-Eemhaven            4.750000   147.000000
